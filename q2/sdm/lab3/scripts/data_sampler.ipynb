# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import datetime as dt
import random
import uuid
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## People Dataset

# %% [markdown]
# We read our reference dataset

# %%
df = pd.read_csv('../../lab1/data/sampleArticle.csv')

# %% [markdown]
# We randomly determine if a person is an author, reviewer, chairperson or editor. In our reality, at the moment, we do not consider that a person can be two things at the same time.

# %%
people_types = {'Author': 0.5, 'Reviewer': 0.3, 'Editor': 0.1, 'Chairperson': 0.1}
def randomPersonType(_):
    choice = np.random.choice(list(people_types.keys()), p=list(people_types.values()))
    return choice

# %%
people = np.unique(df['correspondingAuthor'].values)
people_ids = [uuid.uuid4().hex for _ in range(len(people))]

people_df = pd.DataFrame({'Name': people, 'ID': people_ids})
people_df['Type'] = ''
people_df['Type'] = people_df.apply(randomPersonType, axis=1)

people_df
# Out:
#                      Name                                ID      Type
# 0           A. Battermann  84840ca3f95546298476ddf23fb840e7    Author
# 1    Aaron Pratt Shepherd  97ac227865a64c9baea6e5d7458bf343  Reviewer
# 2       Abdelouahed Hamdi  73a4935f93514f36a9c5a8e695e4a3fc  Reviewer
# 3         Aceil Al-Khatib  ad51da81a4d64a40a3f53b5d6640e5ec  Reviewer
# 4            Adam Briggle  6b48250a5f164bdc9ba00956bc3c49b4    Author
# ..                    ...                               ...       ...
# 658           Yotam Lurie  5845c49a143c49fe9edb529479d09058    Author
# 659   Yuan-Hsuan Lee 0001  163b173a3bc7474e907a51bbf9a640be    Editor
# 660       Yue Liang Zheng  5f6edb4530a44a4890dfba06f000fb85  Reviewer
# 661             Zach Piso  367939b9397344f08a901295b10c14b2    Author
# 662          Zubin Master  bc02617069ca43df9259a5e4791941aa    Editor
#
# [663 rows x 3 columns]

# %% [markdown]
# ### Exporting People Dataset

# %%
people_df.to_csv('../data/people.csv')

# %% [markdown]
# ## Area Dataset

# %%
areas = ['MachineLearning', 'Databases', 'NaturalLanguageProcessing', 'ArtificialIntelligence']
keywords = [['supervised learning', 'unsupervised learning', 'deep learning', 'neural networks', 'data mining'],
            ['relational database', 'SQL', 'NoSQL', 'data modeling', 'database design'],
            ['text processing', 'sentiment analysis', 'language modeling', 'information retrieval', 'part-of-speech tagging'],
            ['knowledge representation', 'expert systems', 'robotics', 'computer vision', 'cognitive computing']]

area_df = pd.DataFrame({'ID': areas, 'Keywords': keywords})
area_df
# Out:
#                           ID                                                                                                 Keywords
# 0            MachineLearning                [supervised learning, unsupervised learning, deep learning, neural networks, data mining]
# 1                  Databases                                        [relational database, SQL, NoSQL, data modeling, database design]
# 2  NaturalLanguageProcessing  [text processing, sentiment analysis, language modeling, information retrieval, part-of-speech tagging]
# 3     ArtificialIntelligence               [knowledge representation, expert systems, robotics, computer vision, cognitive computing]

# %% [markdown]
# ### Exporting Area Dataset

# %%
area_df.to_csv('../data/area.csv')

# %% [markdown]
# ## Venue Dataset

# %%
conference_types = {'RegularConference': 0.5, 'Workshop': 0.3, 'Symposium': 0.1, 'ExpertGroups': 0.1}
def randomConferenceType(_):
    choice = np.random.choice(list(conference_types.keys()), p=list(conference_types.values()))
    return choice

# %%
area_df = pd.read_csv('../data/area.csv')
def randomArea(_):
    choice = np.random.choice(area_df['ID'])
    return choice

# %%
people_df = pd.read_csv('../data/people.csv')
def randomResponsible(row):
    if row['Type'] == 'Conference':
        options = people_df.loc[people_df['Type'] == 'Chairperson', 'ID'].values
    else:
        options = people_df.loc[people_df['Type'] == 'Editor', 'ID'].values

    # print(options)

    choice = np.random.choice(options)

    res = people_df.loc[people_df['ID'] == choice, ['Name', 'ID']]

    # print(res.values)

    return res.values[0]

# %%
# Real data for conferences
conference_data = {'Type': ['Conference'] * 15,
                   'ID': ['CVPR', 'NeurIPS', 'ICML', 'ACL', 'EMNLP', 'AAAI', 'ICLR', 'COLT', 'SIGGRAPH', 'SIGCOMM', 'INFOCOM', 'MobiCom', 'UbiComp', 'CHI', 'UIST'],
                   'Name': ['IEEE/CVF Conference on Computer Vision and Pattern Recognition',
                            'Conference on Neural Information Processing Systems',
                            'International Conference on Machine Learning',
                            'Association for Computational Linguistics',
                            'Empirical Methods in Natural Language Processing',
                            'Association for the Advancement of Artificial Intelligence',
                            'International Conference on Learning Representations',
                            'Conference on Learning Theory',
                            'Special Interest Group on Computer Graphics and Interactive Techniques Conference',
                            'Special Interest Group on Data Communications Conference',
                            'IEEE International Conference on Computer Communications',
                            'ACM International Conference on Mobile Computing and Networking',
                            'International Joint Conference on Pervasive and Ubiquitous Computing',
                            'Conference on Human Factors in Computing Systems',
                            'ACM Symposium on User Interface Software and Technology']}

# Real data for journals
journal_data = {'Type': ['Journal'] * 15,
                'ID': ['JMLR', 'IEEE-TKDE', 'IEEE-TPAMI', 'ACM-TIST', 'JASIST', 'IEEE-DS', 'ACM-CSUR', 'TOIS', 'IJCV', 'JASA', 'TPAMI', 'MLJ', 'TNNLS', 'JML', 'AI'],
                'Name': ['Journal of Machine Learning Research',
                         'IEEE Transactions on Knowledge and Data Engineering',
                         'IEEE Transactions on Pattern Analysis and Machine Intelligence',
                         'ACM Transactions on Intelligent Systems and Technology',
                         'Journal of the Association for Information Science and Technology',
                         'IEEE Data Science and Engineering',
                         'ACM Computing Surveys',
                         'ACM Transactions on Information Systems',
                         'International Journal of Computer Vision',
                         'Journal of the American Statistical Association',
                         'IEEE Transactions on Pattern Analysis and Machine Intelligence',
                         'Machine Learning Journal',
                         'IEEE Transactions on Neural Networks and Learning Systems',
                         'Journal of Machine Learning',
                         'Artificial Intelligence Journal']}

# Concatenate the dataframes and shuffle the rows
venue_df = pd.concat([pd.DataFrame(conference_data), pd.DataFrame(journal_data)])
venue_df = venue_df.sample(frac=1).reset_index(drop=True)

# Assigning conference type to venues which are conferences
venue_df.loc[venue_df['Type'] == 'Conference', 'ConferenceType'] = venue_df.apply(randomConferenceType, axis=1)

venue_df['Area'] = venue_df.apply(randomArea, axis=1)

venue_df[['ResponsibleName', 'ResponsibleID']] = venue_df.apply(randomResponsible, axis=1, result_type='expand')

venue_df
# Out:
#           Type          ID                                                                               Name     ConferenceType                       Area        ResponsibleName                     ResponsibleID
# 0   Conference        ICML                                       International Conference on Machine Learning           Workshop                  Databases          William Bülow  d0242381fb9c472f8397a9914c26f80a
# 1   Conference        ICLR                               International Conference on Learning Representations          Symposium  NaturalLanguageProcessing        David G. Larman  10b31ee210d64c40b17d48fafec4aa5c
# 2      Journal         JML                                                        Journal of Machine Learning                NaN            MachineLearning       Hugh P. Shanahan  c931ed8f1b8b4dedb3c82b7c9a19083b
# 3      Journal       TNNLS                          IEEE Transactions on Neural Networks and Learning Systems                NaN                  Databases          Marty J. Wolf  024bb4fa0c2d4f28b15353bdf9f1d6fc
# 4   Conference       EMNLP                                   Empirical Methods in Natural Language Processing  RegularConference                  Databases        David G. Larman  10b31ee210d64c40b17d48fafec4aa5c
# 5   Conference    SIGGRAPH  Special Interest Group on Computer Graphics and Interactive Techniques Conference  RegularConference                  Databases           Frank Manola  ad8060f4684542f9bc6d0b52a2ce8229
# 6   Conference     UbiComp               International Joint Conference on Pervasive and Ubiquitous Computing       ExpertGroups                  Databases     Ralph J. Greenspan  264ab3cc58eb4c2f94567c1e719181de
# 7      Journal        JASA                                    Journal of the American Statistical Association                NaN     ArtificialIntelligence  Raheleh Heidari Feidt  a00da097d1604fc2ad1c497e2ac4ee5a
# 8      Journal      JASIST                  Journal of the Association for Information Science and Technology                NaN            MachineLearning        Tankred Rautert  e24250e44b664f7e99aa3fb10944ad6c
# 9      Journal  IEEE-TPAMI                     IEEE Transactions on Pattern Analysis and Machine Intelligence                NaN  NaturalLanguageProcessing           Helmut Seidl  ab7216a18d054bfdbf06472b472bef11
# 10  Conference        AAAI                         Association for the Advancement of Artificial Intelligence  RegularConference            MachineLearning         Betty B. Chaar  0dca73caefd14f2cb0904fb9feeac6e1
# 11     Journal     IEEE-DS                                                  IEEE Data Science and Engineering                NaN     ArtificialIntelligence        Thomas R. Scott  9f35d5a5899646f38b0e37a14b79cde3
# 12  Conference        COLT                                                      Conference on Learning Theory           Workshop     ArtificialIntelligence        David G. Larman  10b31ee210d64c40b17d48fafec4aa5c
# 13  Conference     MobiCom                    ACM International Conference on Mobile Computing and Networking  RegularConference  NaturalLanguageProcessing            Rolf Sander  6620537386704472ad3f6f733571727a
# 14     Journal        TOIS                                            ACM Transactions on Information Systems                NaN     ArtificialIntelligence      Alexander Hevelke  f130f159e7f340d18e5f8f8d3f3fa47f
# 15     Journal        JMLR                                               Journal of Machine Learning Research                NaN     ArtificialIntelligence         Andrzej Górski  0af1bf3cc8ca4630adc77ca065c74f90
# 16     Journal    ACM-TIST                             ACM Transactions on Intelligent Systems and Technology                NaN     ArtificialIntelligence       Raymond A. Lorie  786dc940459345d28a5ceee827fc3fb0
# 17  Conference         CHI                                   Conference on Human Factors in Computing Systems  RegularConference                  Databases        David G. Larman  10b31ee210d64c40b17d48fafec4aa5c
# 18     Journal    ACM-CSUR                                                              ACM Computing Surveys                NaN     ArtificialIntelligence            Dieter Baum  2303f7a2ad2a4f91b1c027e21ccc34ea
# 19  Conference     SIGCOMM                           Special Interest Group on Data Communications Conference  RegularConference                  Databases           Reiner Horst  d3d109cc225a4046b9a19686e337f74e
# 20  Conference        UIST                            ACM Symposium on User Interface Software and Technology  RegularConference     ArtificialIntelligence     Norbert Th. Müller  3e45921e13194a94a6da5f5b4b8d9d22
# 21     Journal          AI                                                    Artificial Intelligence Journal                NaN     ArtificialIntelligence        Weishu Liu 0001  f03d1c7f6c36471da0ac4055584b67fa
# 22  Conference         ACL                                          Association for Computational Linguistics           Workshop  NaturalLanguageProcessing               Noam Paz  8045cbce941d473388b62f680c7b5230
# 23  Conference     INFOCOM                           IEEE International Conference on Computer Communications       ExpertGroups                  Databases   Elisabeth Neugebauer  e2fe17a825c44893840eb87160e6b15d
# 24     Journal         MLJ                                                           Machine Learning Journal                NaN                  Databases          Karin Neuhold  2154f5c6e9994b9dbda02e5ed3d8e3dc
# 25  Conference     NeurIPS                                Conference on Neural Information Processing Systems       ExpertGroups  NaturalLanguageProcessing      Markus Wiegelmann  9b49622bcb6a4419ae11297e92ac4034
# 26     Journal       TPAMI                     IEEE Transactions on Pattern Analysis and Machine Intelligence                NaN            MachineLearning    Cristian Timmermann  f535305ad8664bb1addce449156af6e9
# 27     Journal        IJCV                                           International Journal of Computer Vision                NaN  NaturalLanguageProcessing       Charles Verharen  090f9a633a924f068968d34d74d3d541
# 28  Conference        CVPR                     IEEE/CVF Conference on Computer Vision and Pattern Recognition  RegularConference            MachineLearning          Michael Klein  a27f6af0753742e18deb90eece5f1b92
# 29     Journal   IEEE-TKDE                                IEEE Transactions on Knowledge and Data Engineering                NaN  NaturalLanguageProcessing     Brian C. Martinson  4b43b31ea91d41ec94ee96bf05b4aaf5

# %%
venue_df.to_csv('../data/venue.csv')

# %% [markdown]
# ## Volumes Dataset

# %%
journals = pd.read_csv('../data/venue.csv')

journals = np.unique(journals.loc[journals['Type'] == 'Journal', 'ID'].values)

# create a list of possible volume names
journal_ids = []
volume_names = []
years = []
for journal_name in journals:
    # generate 10 possible volume names for each journal name
    start_year = random.randint(1995, 2005)
    for i in range(1, 11):
        journal_ids.append(journal_name)
        volume_names.append(journal_name + '-Volume-' + str(i))
        years.append(start_year+i)

# create a pandas dataframe from the list of volume names
volume_df = pd.DataFrame({'JournalID': journal_ids, 'VolumeID': volume_names, 'volumeYear': years})

volume_df
# Out:
#       JournalID              VolumeID  volumeYear
# 0      ACM-CSUR     ACM-CSUR-Volume-1        2004
# 1      ACM-CSUR     ACM-CSUR-Volume-2        2005
# 2      ACM-CSUR     ACM-CSUR-Volume-3        2006
# 3      ACM-CSUR     ACM-CSUR-Volume-4        2007
# 4      ACM-CSUR     ACM-CSUR-Volume-5        2008
# 5      ACM-CSUR     ACM-CSUR-Volume-6        2009
# 6      ACM-CSUR     ACM-CSUR-Volume-7        2010
# 7      ACM-CSUR     ACM-CSUR-Volume-8        2011
# 8      ACM-CSUR     ACM-CSUR-Volume-9        2012
# 9      ACM-CSUR    ACM-CSUR-Volume-10        2013
# 10     ACM-TIST     ACM-TIST-Volume-1        2005
# 11     ACM-TIST     ACM-TIST-Volume-2        2006
# 12     ACM-TIST     ACM-TIST-Volume-3        2007
# 13     ACM-TIST     ACM-TIST-Volume-4        2008
# 14     ACM-TIST     ACM-TIST-Volume-5        2009
# 15     ACM-TIST     ACM-TIST-Volume-6        2010
# 16     ACM-TIST     ACM-TIST-Volume-7        2011
# 17     ACM-TIST     ACM-TIST-Volume-8        2012
# 18     ACM-TIST     ACM-TIST-Volume-9        2013
# 19     ACM-TIST    ACM-TIST-Volume-10        2014
# 20           AI           AI-Volume-1        2005
# 21           AI           AI-Volume-2        2006
# 22           AI           AI-Volume-3        2007
# 23           AI           AI-Volume-4        2008
# 24           AI           AI-Volume-5        2009
# 25           AI           AI-Volume-6        2010
# 26           AI           AI-Volume-7        2011
# 27           AI           AI-Volume-8        2012
# 28           AI           AI-Volume-9        2013
# 29           AI          AI-Volume-10        2014
# 30      IEEE-DS      IEEE-DS-Volume-1        2004
# 31      IEEE-DS      IEEE-DS-Volume-2        2005
# 32      IEEE-DS      IEEE-DS-Volume-3        2006
# 33      IEEE-DS      IEEE-DS-Volume-4        2007
# 34      IEEE-DS      IEEE-DS-Volume-5        2008
# 35      IEEE-DS      IEEE-DS-Volume-6        2009
# 36      IEEE-DS      IEEE-DS-Volume-7        2010
# 37      IEEE-DS      IEEE-DS-Volume-8        2011
# 38      IEEE-DS      IEEE-DS-Volume-9        2012
# 39      IEEE-DS     IEEE-DS-Volume-10        2013
# 40    IEEE-TKDE    IEEE-TKDE-Volume-1        1998
# 41    IEEE-TKDE    IEEE-TKDE-Volume-2        1999
# 42    IEEE-TKDE    IEEE-TKDE-Volume-3        2000
# 43    IEEE-TKDE    IEEE-TKDE-Volume-4        2001
# 44    IEEE-TKDE    IEEE-TKDE-Volume-5        2002
# 45    IEEE-TKDE    IEEE-TKDE-Volume-6        2003
# 46    IEEE-TKDE    IEEE-TKDE-Volume-7        2004
# 47    IEEE-TKDE    IEEE-TKDE-Volume-8        2005
# 48    IEEE-TKDE    IEEE-TKDE-Volume-9        2006
# 49    IEEE-TKDE   IEEE-TKDE-Volume-10        2007
# 50   IEEE-TPAMI   IEEE-TPAMI-Volume-1        2000
# 51   IEEE-TPAMI   IEEE-TPAMI-Volume-2        2001
# 52   IEEE-TPAMI   IEEE-TPAMI-Volume-3        2002
# 53   IEEE-TPAMI   IEEE-TPAMI-Volume-4        2003
# 54   IEEE-TPAMI   IEEE-TPAMI-Volume-5        2004
# 55   IEEE-TPAMI   IEEE-TPAMI-Volume-6        2005
# 56   IEEE-TPAMI   IEEE-TPAMI-Volume-7        2006
# 57   IEEE-TPAMI   IEEE-TPAMI-Volume-8        2007
# 58   IEEE-TPAMI   IEEE-TPAMI-Volume-9        2008
# 59   IEEE-TPAMI  IEEE-TPAMI-Volume-10        2009
# 60         IJCV         IJCV-Volume-1        1997
# 61         IJCV         IJCV-Volume-2        1998
# 62         IJCV         IJCV-Volume-3        1999
# 63         IJCV         IJCV-Volume-4        2000
# 64         IJCV         IJCV-Volume-5        2001
# 65         IJCV         IJCV-Volume-6        2002
# 66         IJCV         IJCV-Volume-7        2003
# 67         IJCV         IJCV-Volume-8        2004
# 68         IJCV         IJCV-Volume-9        2005
# 69         IJCV        IJCV-Volume-10        2006
# 70         JASA         JASA-Volume-1        1997
# 71         JASA         JASA-Volume-2        1998
# 72         JASA         JASA-Volume-3        1999
# 73         JASA         JASA-Volume-4        2000
# 74         JASA         JASA-Volume-5        2001
# 75         JASA         JASA-Volume-6        2002
# 76         JASA         JASA-Volume-7        2003
# 77         JASA         JASA-Volume-8        2004
# 78         JASA         JASA-Volume-9        2005
# 79         JASA        JASA-Volume-10        2006
# 80       JASIST       JASIST-Volume-1        2003
# 81       JASIST       JASIST-Volume-2        2004
# 82       JASIST       JASIST-Volume-3        2005
# 83       JASIST       JASIST-Volume-4        2006
# 84       JASIST       JASIST-Volume-5        2007
# 85       JASIST       JASIST-Volume-6        2008
# 86       JASIST       JASIST-Volume-7        2009
# 87       JASIST       JASIST-Volume-8        2010
# 88       JASIST       JASIST-Volume-9        2011
# 89       JASIST      JASIST-Volume-10        2012
# 90          JML          JML-Volume-1        2003
# 91          JML          JML-Volume-2        2004
# 92          JML          JML-Volume-3        2005
# 93          JML          JML-Volume-4        2006
# 94          JML          JML-Volume-5        2007
# 95          JML          JML-Volume-6        2008
# 96          JML          JML-Volume-7        2009
# 97          JML          JML-Volume-8        2010
# 98          JML          JML-Volume-9        2011
# 99          JML         JML-Volume-10        2012
# 100        JMLR         JMLR-Volume-1        1996
# 101        JMLR         JMLR-Volume-2        1997
# 102        JMLR         JMLR-Volume-3        1998
# 103        JMLR         JMLR-Volume-4        1999
# 104        JMLR         JMLR-Volume-5        2000
# 105        JMLR         JMLR-Volume-6        2001
# 106        JMLR         JMLR-Volume-7        2002
# 107        JMLR         JMLR-Volume-8        2003
# 108        JMLR         JMLR-Volume-9        2004
# 109        JMLR        JMLR-Volume-10        2005
# 110         MLJ          MLJ-Volume-1        2003
# 111         MLJ          MLJ-Volume-2        2004
# 112         MLJ          MLJ-Volume-3        2005
# 113         MLJ          MLJ-Volume-4        2006
# 114         MLJ          MLJ-Volume-5        2007
# 115         MLJ          MLJ-Volume-6        2008
# 116         MLJ          MLJ-Volume-7        2009
# 117         MLJ          MLJ-Volume-8        2010
# 118         MLJ          MLJ-Volume-9        2011
# 119         MLJ         MLJ-Volume-10        2012
# 120       TNNLS        TNNLS-Volume-1        1998
# 121       TNNLS        TNNLS-Volume-2        1999
# 122       TNNLS        TNNLS-Volume-3        2000
# 123       TNNLS        TNNLS-Volume-4        2001
# 124       TNNLS        TNNLS-Volume-5        2002
# 125       TNNLS        TNNLS-Volume-6        2003
# 126       TNNLS        TNNLS-Volume-7        2004
# 127       TNNLS        TNNLS-Volume-8        2005
# 128       TNNLS        TNNLS-Volume-9        2006
# 129       TNNLS       TNNLS-Volume-10        2007
# 130        TOIS         TOIS-Volume-1        1996
# 131        TOIS         TOIS-Volume-2        1997
# 132        TOIS         TOIS-Volume-3        1998
# 133        TOIS         TOIS-Volume-4        1999
# 134        TOIS         TOIS-Volume-5        2000
# 135        TOIS         TOIS-Volume-6        2001
# 136        TOIS         TOIS-Volume-7        2002
# 137        TOIS         TOIS-Volume-8        2003
# 138        TOIS         TOIS-Volume-9        2004
# 139        TOIS        TOIS-Volume-10        2005
# 140       TPAMI        TPAMI-Volume-1        2005
# 141       TPAMI        TPAMI-Volume-2        2006
# 142       TPAMI        TPAMI-Volume-3        2007
# 143       TPAMI        TPAMI-Volume-4        2008
# 144       TPAMI        TPAMI-Volume-5        2009
# 145       TPAMI        TPAMI-Volume-6        2010
# 146       TPAMI        TPAMI-Volume-7        2011
# 147       TPAMI        TPAMI-Volume-8        2012
# 148       TPAMI        TPAMI-Volume-9        2013
# 149       TPAMI       TPAMI-Volume-10        2014

# %%
volume_df.to_csv('../data/volume.csv')

# %% [markdown]
# ## Proceedings Dataset

# %%
proceedings = pd.read_csv('../data/venue.csv')

proceedings = np.unique(proceedings.loc[proceedings['Type'] == 'Conference', 'ID'].values)

# create a list of possible volume names
conference_ids = []
proceeding_names = []
years = []
for proceeding_name in proceedings:
    # generate 10 possible volume names for each journal name
    start_year = random.randint(1995, 2005)
    for i in range(1, 11):
        conference_ids.append(proceeding_name)
        proceeding_names.append(proceeding_name + '-Proceeding-' + str(i))
        years.append(start_year+i)

# create a pandas dataframe from the list of volume names
proceeding_df = pd.DataFrame({'ConferenceID': conference_ids, 'ProceedingID': proceeding_names, 'proceedingsYear': years})

proceeding_df
# Out:
#     ConferenceID            ProceedingID  proceedingsYear
# 0           AAAI       AAAI-Proceeding-1             1999
# 1           AAAI       AAAI-Proceeding-2             2000
# 2           AAAI       AAAI-Proceeding-3             2001
# 3           AAAI       AAAI-Proceeding-4             2002
# 4           AAAI       AAAI-Proceeding-5             2003
# 5           AAAI       AAAI-Proceeding-6             2004
# 6           AAAI       AAAI-Proceeding-7             2005
# 7           AAAI       AAAI-Proceeding-8             2006
# 8           AAAI       AAAI-Proceeding-9             2007
# 9           AAAI      AAAI-Proceeding-10             2008
# 10           ACL        ACL-Proceeding-1             1999
# 11           ACL        ACL-Proceeding-2             2000
# 12           ACL        ACL-Proceeding-3             2001
# 13           ACL        ACL-Proceeding-4             2002
# 14           ACL        ACL-Proceeding-5             2003
# 15           ACL        ACL-Proceeding-6             2004
# 16           ACL        ACL-Proceeding-7             2005
# 17           ACL        ACL-Proceeding-8             2006
# 18           ACL        ACL-Proceeding-9             2007
# 19           ACL       ACL-Proceeding-10             2008
# 20           CHI        CHI-Proceeding-1             2001
# 21           CHI        CHI-Proceeding-2             2002
# 22           CHI        CHI-Proceeding-3             2003
# 23           CHI        CHI-Proceeding-4             2004
# 24           CHI        CHI-Proceeding-5             2005
# 25           CHI        CHI-Proceeding-6             2006
# 26           CHI        CHI-Proceeding-7             2007
# 27           CHI        CHI-Proceeding-8             2008
# 28           CHI        CHI-Proceeding-9             2009
# 29           CHI       CHI-Proceeding-10             2010
# 30          COLT       COLT-Proceeding-1             2000
# 31          COLT       COLT-Proceeding-2             2001
# 32          COLT       COLT-Proceeding-3             2002
# 33          COLT       COLT-Proceeding-4             2003
# 34          COLT       COLT-Proceeding-5             2004
# 35          COLT       COLT-Proceeding-6             2005
# 36          COLT       COLT-Proceeding-7             2006
# 37          COLT       COLT-Proceeding-8             2007
# 38          COLT       COLT-Proceeding-9             2008
# 39          COLT      COLT-Proceeding-10             2009
# 40          CVPR       CVPR-Proceeding-1             2000
# 41          CVPR       CVPR-Proceeding-2             2001
# 42          CVPR       CVPR-Proceeding-3             2002
# 43          CVPR       CVPR-Proceeding-4             2003
# 44          CVPR       CVPR-Proceeding-5             2004
# 45          CVPR       CVPR-Proceeding-6             2005
# 46          CVPR       CVPR-Proceeding-7             2006
# 47          CVPR       CVPR-Proceeding-8             2007
# 48          CVPR       CVPR-Proceeding-9             2008
# 49          CVPR      CVPR-Proceeding-10             2009
# 50         EMNLP      EMNLP-Proceeding-1             1997
# 51         EMNLP      EMNLP-Proceeding-2             1998
# 52         EMNLP      EMNLP-Proceeding-3             1999
# 53         EMNLP      EMNLP-Proceeding-4             2000
# 54         EMNLP      EMNLP-Proceeding-5             2001
# 55         EMNLP      EMNLP-Proceeding-6             2002
# 56         EMNLP      EMNLP-Proceeding-7             2003
# 57         EMNLP      EMNLP-Proceeding-8             2004
# 58         EMNLP      EMNLP-Proceeding-9             2005
# 59         EMNLP     EMNLP-Proceeding-10             2006
# 60          ICLR       ICLR-Proceeding-1             2006
# 61          ICLR       ICLR-Proceeding-2             2007
# 62          ICLR       ICLR-Proceeding-3             2008
# 63          ICLR       ICLR-Proceeding-4             2009
# 64          ICLR       ICLR-Proceeding-5             2010
# 65          ICLR       ICLR-Proceeding-6             2011
# 66          ICLR       ICLR-Proceeding-7             2012
# 67          ICLR       ICLR-Proceeding-8             2013
# 68          ICLR       ICLR-Proceeding-9             2014
# 69          ICLR      ICLR-Proceeding-10             2015
# 70          ICML       ICML-Proceeding-1             2006
# 71          ICML       ICML-Proceeding-2             2007
# 72          ICML       ICML-Proceeding-3             2008
# 73          ICML       ICML-Proceeding-4             2009
# 74          ICML       ICML-Proceeding-5             2010
# 75          ICML       ICML-Proceeding-6             2011
# 76          ICML       ICML-Proceeding-7             2012
# 77          ICML       ICML-Proceeding-8             2013
# 78          ICML       ICML-Proceeding-9             2014
# 79          ICML      ICML-Proceeding-10             2015
# 80       INFOCOM    INFOCOM-Proceeding-1             2002
# 81       INFOCOM    INFOCOM-Proceeding-2             2003
# 82       INFOCOM    INFOCOM-Proceeding-3             2004
# 83       INFOCOM    INFOCOM-Proceeding-4             2005
# 84       INFOCOM    INFOCOM-Proceeding-5             2006
# 85       INFOCOM    INFOCOM-Proceeding-6             2007
# 86       INFOCOM    INFOCOM-Proceeding-7             2008
# 87       INFOCOM    INFOCOM-Proceeding-8             2009
# 88       INFOCOM    INFOCOM-Proceeding-9             2010
# 89       INFOCOM   INFOCOM-Proceeding-10             2011
# 90       MobiCom    MobiCom-Proceeding-1             1999
# 91       MobiCom    MobiCom-Proceeding-2             2000
# 92       MobiCom    MobiCom-Proceeding-3             2001
# 93       MobiCom    MobiCom-Proceeding-4             2002
# 94       MobiCom    MobiCom-Proceeding-5             2003
# 95       MobiCom    MobiCom-Proceeding-6             2004
# 96       MobiCom    MobiCom-Proceeding-7             2005
# 97       MobiCom    MobiCom-Proceeding-8             2006
# 98       MobiCom    MobiCom-Proceeding-9             2007
# 99       MobiCom   MobiCom-Proceeding-10             2008
# 100      NeurIPS    NeurIPS-Proceeding-1             2005
# 101      NeurIPS    NeurIPS-Proceeding-2             2006
# 102      NeurIPS    NeurIPS-Proceeding-3             2007
# 103      NeurIPS    NeurIPS-Proceeding-4             2008
# 104      NeurIPS    NeurIPS-Proceeding-5             2009
# 105      NeurIPS    NeurIPS-Proceeding-6             2010
# 106      NeurIPS    NeurIPS-Proceeding-7             2011
# 107      NeurIPS    NeurIPS-Proceeding-8             2012
# 108      NeurIPS    NeurIPS-Proceeding-9             2013
# 109      NeurIPS   NeurIPS-Proceeding-10             2014
# 110      SIGCOMM    SIGCOMM-Proceeding-1             2005
# 111      SIGCOMM    SIGCOMM-Proceeding-2             2006
# 112      SIGCOMM    SIGCOMM-Proceeding-3             2007
# 113      SIGCOMM    SIGCOMM-Proceeding-4             2008
# 114      SIGCOMM    SIGCOMM-Proceeding-5             2009
# 115      SIGCOMM    SIGCOMM-Proceeding-6             2010
# 116      SIGCOMM    SIGCOMM-Proceeding-7             2011
# 117      SIGCOMM    SIGCOMM-Proceeding-8             2012
# 118      SIGCOMM    SIGCOMM-Proceeding-9             2013
# 119      SIGCOMM   SIGCOMM-Proceeding-10             2014
# 120     SIGGRAPH   SIGGRAPH-Proceeding-1             2003
# 121     SIGGRAPH   SIGGRAPH-Proceeding-2             2004
# 122     SIGGRAPH   SIGGRAPH-Proceeding-3             2005
# 123     SIGGRAPH   SIGGRAPH-Proceeding-4             2006
# 124     SIGGRAPH   SIGGRAPH-Proceeding-5             2007
# 125     SIGGRAPH   SIGGRAPH-Proceeding-6             2008
# 126     SIGGRAPH   SIGGRAPH-Proceeding-7             2009
# 127     SIGGRAPH   SIGGRAPH-Proceeding-8             2010
# 128     SIGGRAPH   SIGGRAPH-Proceeding-9             2011
# 129     SIGGRAPH  SIGGRAPH-Proceeding-10             2012
# 130         UIST       UIST-Proceeding-1             2000
# 131         UIST       UIST-Proceeding-2             2001
# 132         UIST       UIST-Proceeding-3             2002
# 133         UIST       UIST-Proceeding-4             2003
# 134         UIST       UIST-Proceeding-5             2004
# 135         UIST       UIST-Proceeding-6             2005
# 136         UIST       UIST-Proceeding-7             2006
# 137         UIST       UIST-Proceeding-8             2007
# 138         UIST       UIST-Proceeding-9             2008
# 139         UIST      UIST-Proceeding-10             2009
# 140      UbiComp    UbiComp-Proceeding-1             1997
# 141      UbiComp    UbiComp-Proceeding-2             1998
# 142      UbiComp    UbiComp-Proceeding-3             1999
# 143      UbiComp    UbiComp-Proceeding-4             2000
# 144      UbiComp    UbiComp-Proceeding-5             2001
# 145      UbiComp    UbiComp-Proceeding-6             2002
# 146      UbiComp    UbiComp-Proceeding-7             2003
# 147      UbiComp    UbiComp-Proceeding-8             2004
# 148      UbiComp    UbiComp-Proceeding-9             2005
# 149      UbiComp   UbiComp-Proceeding-10             2006

# %%
proceeding_df.to_csv('../data/proceedings.csv')

# %% [markdown]
# ## Paper Dataset
#
# This dataset will contain papers that are submitted to venues. It will also include published papers. We will deal with making sure these publications are conforming to the constraints later. The constraint is that they must be accepted by at least two reviewers.

# %%
author_df = pd.read_csv('../data/people.csv')
author_df = author_df.loc[author_df['Type'] == 'Author', ['Name', 'ID']]

def randomAuthor(_):
    choice = np.random.choice(author_df['ID'].values)

    # print(choice)

    choice = author_df.loc[author_df['ID'] == choice]

    return choice['Name'].values[0], choice['ID'].values[0]

# %%
venue_df = pd.read_csv('../data/venue.csv')

def randomVenue(_):
    choice = np.random.choice(venue_df['ID'].values)
    choice = venue_df.loc[venue_df['ID'] == choice]

    return choice['Name'].values[0], choice['ID'].values[0], choice['Type'].values[0], choice['ConferenceType'].values[0], choice['Area'].values[0]

# %%
def randomPaperType(type):
    if type == 'Conference':
        return np.random.choice(['FullPaper', 'ShortPaper', 'DemoPaper', 'Poster'], p=[0.4, 0.4, 0.15, 0.05])
    else:
        return np.random.choice(['FullPaper', 'ShortPaper', 'DemoPaper'], p=[0.4, 0.4, 0.2])

# %%
proceedings_df = pd.read_csv('../data/proceedings.csv')
volume_df = pd.read_csv('../data/volume.csv')

def randomPublishedIn(row):
    if row['Published']:

        if row['VenueType'] == 'Conference':
            choices = proceedings_df.loc[proceedings_df['ConferenceID'] == row['VenueID'], 'ProceedingID']
            choice = np.random.choice(choices.values)
        else:
            choices = volume_df.loc[volume_df['JournalID'] == row['VenueID'], 'VolumeID']
            choice = np.random.choice(choices.values)

        return choice
    return ''

# %%
paper_titles = np.unique(df['title'].values)
paper_ids = [uuid.uuid4().hex for _ in range(len(paper_titles))]

paper_df = pd.DataFrame({'ID': paper_ids, 'Title': paper_titles})

paper_df[['Author', 'AuthorID']] = paper_df.apply(randomAuthor, axis=1, result_type='expand')
paper_df[['Venue', 'VenueID', 'VenueType', 'ConferenceType', 'Area']] = paper_df.apply(randomVenue, axis=1, result_type='expand')

paper_df['Published'] = np.random.choice([True, False], size=len(paper_df))

paper_df['PublishedIn'] = paper_df.apply(randomPublishedIn, axis=1)

paper_df['PaperType'] = paper_df['VenueType'].apply(randomPaperType)

# %%
paper_df
# Out:
#                                    ID                                                                                                                                                                                                                                                  Title              Author                          AuthorID                                                                 Venue    VenueID   VenueType     ConferenceType                       Area  Published           PublishedIn   PaperType
# 0    4b817798ae93460b927ad91a2f268027                                                                                                  "'Once more unto the Breach': Professional Responsibility and Computer Ethics" - A Response to: "A Critique of Positive Responsibility in Computing".      Douglas Walton  2f8bc8d0da6543bebad91a01bf4b9603               ACM Symposium on User Interface Software and Technology       UIST  Conference  RegularConference     ArtificialIntelligence      False                         FullPaper
# 1    8e5572c3954b4af4a007efc6f1f49de6                                                                                                                                                                                                               "An Ethics of Commitment for Engineers".      Petra Steffens  ca68767de329494380b3e340f6d12060     Journal of the Association for Information Science and Technology     JASIST     Journal                NaN            MachineLearning      False                         FullPaper
# 2    520adc97848d463d9a62e3887c9e36de                                                                                                              "Broader Impacts" or "Responsible Research and Innovation"? A Comparison of Two Criteria for Funding Research in Science and Engineering.       Lothar Breuer  8d3758f8613c47b6911c755601c10ca0                       Journal of the American Statistical Association       JASA     Journal                NaN     ArtificialIntelligence      False                         DemoPaper
# 3    c32ef10d6ee240518de615e75c8f74a0                                                                                                                                                      "Der Film öded das Publikum" - Zum Aufbau eines maschinenlesbaren Wörterbuchs für deutsche Verben     Knut Jørgen Vie  3a44c271c0a44bc2b2acfa8fd83df557                              International Journal of Computer Vision       IJCV     Journal                NaN  NaturalLanguageProcessing       True        IJCV-Volume-10   DemoPaper
# 4    38a7cfbf99c440b6869f063af9f01a54  "Dictionary Dialog" - Entwurf des Funktionsumfangs für eine Benutzerschnittstelle eines integrierten maschinellen/maschinenunterstützten Übersetzungssystems und prototypische Erstellung der Bildschirmfolge für die Funktion "Semantische Relation"      Don Gotterbarn  7af510c5c64e4221ba3f69376d18ebee                             Association for Computational Linguistics        ACL  Conference           Workshop  NaturalLanguageProcessing       True      ACL-Proceeding-1   FullPaper
# ..                                ...                                                                                                                                                                                                                                                    ...                 ...                               ...                                                                   ...        ...         ...                ...                        ...        ...                   ...         ...
# 981  5a063cc97dfd4c029cfd975bf4ec4b46                                                                                                                                                                                                         tele-TASK - Teleteaching Anywhere Solution Kit           Klaus Lux  1e9439ef6df9446c969098b83535ebe5                   IEEE Transactions on Knowledge and Data Engineering  IEEE-TKDE     Journal                NaN  NaturalLanguageProcessing       True    IEEE-TKDE-Volume-6   FullPaper
# 982  2efe0993224d4ec9a06de661c6c04036                                                                                                                                                                                     tele-TASK - Teleteaching praxistauglich für den Universitätsalltag       Mehmet Aközer  eff3bfc5fb024deba7e130d740b87449  International Joint Conference on Pervasive and Ubiquitous Computing    UbiComp  Conference       ExpertGroups                  Databases       True  UbiComp-Proceeding-5  ShortPaper
# 983  3c7ced5c3da0407fbcd670f0d5609570                                                                                                                                                                                              Über Ansätze zur Darstellung von Konzepten und Prototypen  Burkhard Kehrbusch  428622834e69409da0d116a5dec4a71a                      Conference on Human Factors in Computing Systems        CHI  Conference  RegularConference                  Databases       True      CHI-Proceeding-5   FullPaper
# 984  c17c6986665f4d13be9957388de21bbd                                                                                                                                                                                                                          Über Vergleichskonstruktionen       Dorthie Cross  89725ca6d2234ef2a5c28566a3c031dc                   Conference on Neural Information Processing Systems    NeurIPS  Conference       ExpertGroups  NaturalLanguageProcessing       True  NeurIPS-Proceeding-8  ShortPaper
# 985  8b1c7a38976f44f08a6edfe00f6db564                                                                                                               Über die W's der Textgenerierung: Was, wofür, wo und wie: Wissensbasierte Generierung von informierenden Texten in einem Auskunftssystem   Shannon L. Spruit  4e0154ec812448edb703747b63059263                          International Conference on Machine Learning       ICML  Conference           Workshop                  Databases       True     ICML-Proceeding-7   FullPaper
#
# [986 rows x 12 columns]

# %%
paper_df.to_csv('../data/paper.csv')

# %% [markdown]
# ## Reviews Dataset

# %%
venue_df = pd.read_csv('../data/venue.csv')
paper_df = pd.read_csv('../data/paper.csv')

def getResponsibleId(paper):
    venue = paper_df.loc[paper_df['ID'] == paper, 'Venue']
    responsible = venue_df.loc[venue_df['Name'] == venue.values[0], 'ResponsibleID']

    return responsible.values[0]

def getDecision(paper):
    decision = paper_df.loc[paper_df['ID'] == paper, 'Published']
    return decision.values[0]


review_texts = {
    "Good": [
        "This paper is well-written and provides valuable insights.",
        "The experiments are well-designed and the results are statistically significant.",
        "The authors have addressed all of the reviewers' comments and improved the paper significantly.",
        "The paper presents a novel contribution to the field and is likely to have a high impact.",
        "The writing is clear and concise, making the paper easy to understand.",
    ],
    "Bad": [
        "The paper is poorly written and difficult to follow.",
        "The experiments are poorly designed and the results are not statistically significant.",
        "The authors have not adequately addressed the reviewers' comments, and the paper has not improved significantly.",
        "The paper does not make a significant contribution to the field and is not likely to have a high impact.",
        "The writing is unclear and difficult to understand, making the paper hard to follow.",
    ]
}

def getReviewText(decision):
    if decision:
        choice = np.random.choice(review_texts['Good'])
    else:
        choice = np.random.choice(review_texts['Bad'])
    
    return choice

# %%
paperTitles = pd.read_csv('../data/paper.csv')
paperTitles = np.unique(paperTitles['ID'].values)

reviewers = pd.read_csv('../data/people.csv')
reviewers = np.unique(reviewers.loc[reviewers['Type'] == 'Reviewer', 'ID'].values)

# create a dictionary to store the data
data = {'ReviewID': [], 'PaperID': [], 'ReviewerID': []}

# iterate over each paper name and assign a random set of 2 to 5 reviewers
for paper_name in paperTitles:
    # randomly select the number of reviewers for this paper (2 to 5)
    num_reviewers = np.random.randint(2, 6)
    # randomly select reviewers for this paper without replacement
    paper_reviewers = np.random.choice(reviewers, size=num_reviewers, replace=False)
    # add the paper-reviewer pairs to the dictionary
    for reviewer in paper_reviewers:
        data['ReviewID'].append(uuid.uuid4().hex)
        data['PaperID'].append(paper_name)
        data['ReviewerID'].append(reviewer)

# create a pandas dataframe from the dictionary
review_df = pd.DataFrame(data)

# We retrieve the responsible of the venue in which it was submitted
review_df['ResponsibleID'] = review_df['PaperID'].apply(getResponsibleId)

review_df['Decision'] = review_df['PaperID'].apply(getDecision)
review_df['ReviewText'] = review_df['Decision'].apply(getReviewText)

# %%
review_df
# Out:
#                               ReviewID                           PaperID                        ReviewerID                     ResponsibleID  Decision                                                                                       ReviewText
# 0     21255096ed5f4411a0bad97bc7603b89  0022f58487cd4d048a60e3f0835c4b37  b3fa6cb31ee2433ba1ec61ae51a25ca4  9b49622bcb6a4419ae11297e92ac4034      True  The authors have addressed all of the reviewers' comments and improved the paper significantly.
# 1     b4bb533329484335bb05cfd01375000b  0022f58487cd4d048a60e3f0835c4b37  d605e52b1e9b4d64a4b89f928c86e35a  9b49622bcb6a4419ae11297e92ac4034      True                           The writing is clear and concise, making the paper easy to understand.
# 2     3025b88bfc0444c486a657d4e43fced9  0022f58487cd4d048a60e3f0835c4b37  7463d194788843ab8e3a506dccfa142f  9b49622bcb6a4419ae11297e92ac4034      True                 The experiments are well-designed and the results are statistically significant.
# 3     938e13fb85c647529b7051e5acde0c94  0022f58487cd4d048a60e3f0835c4b37  3112b9f941af49f2accd12414e380bf9  9b49622bcb6a4419ae11297e92ac4034      True        The paper presents a novel contribution to the field and is likely to have a high impact.
# 4     4e07b0859b794ae89f8008abdaee0b58  0022f58487cd4d048a60e3f0835c4b37  2dfc5141adb6400192c2049b87311ca4  9b49622bcb6a4419ae11297e92ac4034      True                           The writing is clear and concise, making the paper easy to understand.
# ...                                ...                               ...                               ...                               ...       ...                                                                                              ...
# 3467  fff519e50b98497d8e5116120b5c0e1a  fe878e9b728b4e79951a0ee72a59596a  0fb5aefda6884cefaed1364e81478c6f  f130f159e7f340d18e5f8f8d3f3fa47f      True                                       This paper is well-written and provides valuable insights.
# 3468  99bf75483a4d4224b8c11eb4db38ed85  fe878e9b728b4e79951a0ee72a59596a  5ebb05e58f204620a5c6d9969709d0b8  f130f159e7f340d18e5f8f8d3f3fa47f      True                           The writing is clear and concise, making the paper easy to understand.
# 3469  87f14fcd49214eafaaea674e77bd71f3  febc52e6ce44403eb453d938727bf289  f673c6fdf08e45f3b3862fc11c28bc57  f03d1c7f6c36471da0ac4055584b67fa      True        The paper presents a novel contribution to the field and is likely to have a high impact.
# 3470  195b50ac9d76410c9c1bedf1e4d96ebc  febc52e6ce44403eb453d938727bf289  32c7e38a3ae54d609e59d05036788258  f03d1c7f6c36471da0ac4055584b67fa      True  The authors have addressed all of the reviewers' comments and improved the paper significantly.
# 3471  bf0d351732ae4869b7c08d4e2827dc18  febc52e6ce44403eb453d938727bf289  edaa0045c3fe48198c0395e2f75f5bfd  f03d1c7f6c36471da0ac4055584b67fa      True                           The writing is clear and concise, making the paper easy to understand.
#
# [3472 rows x 6 columns]

# %%
review_df.to_csv('../data/review.csv')
